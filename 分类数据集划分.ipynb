# %%
import os
import random
import shutil
import csv
import numpy as np
def CopyFile(imageDir,test_rate,save_test_dir,save_train_dir):#三个参数，第一个为每个类别的所有图像在计算机中的位置
    #第二个为copy的图片数目所占总的比例，最后一个为移动的图片保存的位置，
    image_number = len(imageDir)  #图片总数目
    test_number = int(image_number * test_rate)#要移动的图片数目
    print("要移动到%s目录下的图片数目为:%d"%(save_test_dir,test_number))
    test_samples = random.sample(imageDir, test_number)#随机截取列表imageDir中数目为test_number的元素
 # copy图像到目标文件夹
    if not os.path.exists(save_test_dir):
        os.makedirs(save_test_dir)
        print("save_test_dir has been created successfully!")
    else:
        print("save_test_dir already exited!")
    if not os.path.exists(save_train_dir):
        os.makedirs(save_train_dir)
        print("save_train_dir has been created successfully!")
    else:
        print("save_train_dir already exited!")
    for i,j in enumerate(test_samples):
        shutil.copy(test_samples[i], save_test_dir+test_samples[i].split("/")[-1])
    print("tets移动完成！")
    for train_imgs in imageDir:
        if train_imgs not in test_samples:
            shutil.copy(train_imgs, save_train_dir+train_imgs.split("/")[-1])
    print("train移动完成")
#只需给定file_path、test_rate即可完成整个任务
#原始路径+分割比例
################################
file_path="Tea_YN Dataset/"
test_rate = 0.2
################################
file_dirs=os.listdir(file_path)
origion_paths=[]
save_test_dirs=[]
save_train_dirs=[]
for path in file_dirs:
   origion_paths.append(file_path+"/"+path+"/")
   save_train_dirs.append("train/"+path+"/")
   save_test_dirs.append("test/"+path+"/")
for i,origion_path in enumerate(origion_paths):
    image_list = os.listdir(origion_path) #获得原始路径下的所有图片的name（默认路径下都是图片）
    image_Dir=[]
    for x,y in enumerate(image_list):
        image_Dir.append (os.path.join(origion_path, y))
    print("%s目录下共有%d张图片！"%(origion_path,len(image_Dir)))
    CopyFile(image_Dir,test_rate,save_test_dirs[i],save_train_dirs[i])
print("all datas has been moved successfully!")
# Out:
# Tea_YN Dataset//bud_blight/目录下共有718张图片！
# 要移动到test/bud_blight/目录下的图片数目为:143
# save_test_dir has been created successfully!
# save_train_dir has been created successfully!
# tets移动完成！
# train移动完成
# Tea_YN Dataset//circle_red_star/目录下共有156张图片！
# 要移动到test/circle_red_star/目录下的图片数目为:31
# save_test_dir has been created successfully!
# save_train_dir has been created successfully!
# tets移动完成！
# train移动完成
# Tea_YN Dataset//grey_blight/目录下共有92张图片！
# 要移动到test/grey_blight/目录下的图片数目为:18
# save_test_dir has been created successfully!
# save_train_dir has been created successfully!
# tets移动完成！
# train移动完成
# Tea_YN Dataset//insect_pest/目录下共有111张图片！
# 要移动到test/insect_pest/目录下的图片数目为:22
# save_test_dir has been created successfully!
# save_train_dir has been created successfully!
# tets移动完成！
# train移动完成
# Tea_YN Dataset//leaf_blight/目录下共有97张图片！
# 要移动到test/leaf_blight/目录下的图片数目为:19
# save_test_dir has been created successfully!
# save_train_dir has been created successfully!
# tets移动完成！
# train移动完成
# Tea_YN Dataset//Phyllosticta_fheaefolia Hara/目录下共有330张图片！
# 要移动到test/Phyllosticta_fheaefolia Hara/目录下的图片数目为:66
# save_test_dir has been created successfully!
# save_train_dir has been created successfully!
# tets移动完成！
# train移动完成
# Tea_YN Dataset//spot/目录下共有65张图片！
# 要移动到test/spot/目录下的图片数目为:13
# save_test_dir has been created successfully!
# save_train_dir has been created successfully!
# tets移动完成！
# train移动完成
# all datas has been moved successfully!

# %%
ls
# Out:
#  驱动器 C 中的卷没有标签。
#  卷的序列号是 7A80-61DF
#
#  C:\Users\Administrator\Desktop 的目录
#
# 2022/08/30  10:11    <DIR>          .
# 2022/08/30  10:11    <DIR>          ..
# 2022/08/30  10:11    <DIR>          .ipynb_checkpoints
# 2022/08/27  15:33            41,440 20220905内容大纲.pptx
# 2022/08/27  10:29    <DIR>          CT
# 2022/08/29  09:54               844 DenseBiasNet_180DSC.csv
# 2022/08/25  10:07               824 DenseBiasNet_DSC.csv
# 2022/07/07  15:04             2,369 Excel 2016.lnk
# 2022/08/17  15:55             1,331 FurMark.lnk
# 2022/08/29  16:04               829 PotPlayer.lnk
# 2022/08/27  09:29    <DIR>          Tea_YN Dataset
# 2022/08/29  11:09     3,022,025,543 Tea_YN Dataset.zip
# 2022/08/29  10:09               833 TransDBiasNet_adp_96_180_DSC.csv
# 2022/08/29  10:05               841 TransDBiasNet_adp_96_200_DSC.csv
# 2022/08/23  10:17               844 Visual Studio Code.lnk
# 2022/07/07  15:04             2,395 Word 2016.lnk
# 2022/08/26  13:25               569 阿里云盘.lnk
# 2022/08/29  11:09             1,258 百度网盘.lnk
# 2022/08/29  15:26           315,289 报账预印.pdf
# 2022/08/30  10:11    <DIR>          病虫害
# 2022/08/26  15:42    <DIR>          发票
# 2022/08/30  10:09                72 分类数据集划分.ipynb
# 2022/08/29  15:36            39,333 寇旭鹏大兴机场发票.pdf
# 2022/08/23  09:49               777 微信.lnk
# 2022/08/27  10:32               743 小赛看看 DICOM Viewer.lnk
#               18 个文件  3,022,436,134 字节
#                7 个目录 418,258,702,336 可用字节
